# %%
import pandas as pd
import numpy as np

# Show all rows
pd.set_option("display.max_rows", None)

# Show all columns
pd.set_option("display.max_columns", None)

# Make sure wide DataFrames don't wrap
pd.set_option("display.width", None)

# Show the full content of each column (no '...')
pd.set_option("display.max_colwidth", None)

# %%
file_path = r"C:\Users\Arunkumara\Downloads\DRGHistoricalReviewInformation_11182025.txt"

df_hist = pd.read_csv(file_path, sep='|', dtype=str, low_memory=False)

print(df_hist.info())
df_hist.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886092 entries, 0 to 886091
# Columns: 282 entries, Payor to AdjustedSavings
# dtypes: object(282)
# memory usage: 1.9+ GB
# None
#      Payor claimid Client         Control_ID  Claim_Number PaymentType  \
# 0  UHC CSP  758656     NY  EXPR101623-340919  23N652771000      PrePay
# 1  UHC CSP  758732     NY  EXPR101723-341037  23O144833200      PrePay
# 2  UHC CSP  758762     NY  EXPR101723-341041  23O921646100      PrePay
# 3  UHC CSP  393206     IA  IAPT2022-01-30899  21A985906501     PostPay
# 4  UHC CSP  393210     IA  IAPT2022-01-30894  21I856356401     PostPay
#
#   Group_Type            Payments     Tax_ID   Provider_ID  \
# 0         01            15948.41  141340054  000334584002
# 1         01            10477.92  141348692  000258115003
# 2         01            11532.33  160762843  000657681001
# 3         01  12227.790000000001  420698265  000023698002
# 4         01            10804.16  420698265  000023698002
#
#                  HospitalName LOS                        DISP_Code ADRG  \
# 0  ST LUKES CORNWALL HOSPITAL   9          02-TRNSF ACUTE CARE FAC  432
# 1          ST PETERS HOSPITAL   5                  01-ROUTINE/HOME  919
# 2      KENMORE MERCY HOSPITAL   3  03-TRNSF TO SKILLED NURSING FAC  871
# 3              ALLEN HOSPITAL   2                  01-ROUTINE/HOME  854
# 4              ALLEN HOSPITAL   5  03-TRNSF TO SKILLED NURSING FAC  871
#
#   DischargeYear DischargeMonth AGE A_CCCount A_MCCCount B_CCCount B_MCCCount  \
# 0          2023              9  69         2          2         2          2
# 1          2023              9  62         4          2         4          2
# 2          2023             10  77         7          3         7          0
# 3          2021              1  60         3          0         2          0
# 4          2021              7  70         2          3         2          3
#
#         LOB                          MRREQ                MRREC  PRIM_DX  \
# 0  NYCARE    2023-10-17 16:38:04.687000000  2023-11-08 00:00:00    K7030
# 1  NYCARE    2023-10-17 16:30:09.853000000  2023-10-20 00:00:00  T85698A
# 2  NYCARE    2023-10-17 16:25:58.280000000  2023-12-14 00:00:00     A419
# 3    IADSNP  2022-01-06 13:33:35.747000000  2022-01-20 00:00:00     A419
# 4    IADSNP  2022-01-06 13:33:36.557000000  2022-01-19 00:00:00     A419
#
#           A_DX2        A_DX3        A_DX4       A_DX5       A_DX6  \
# 0   I8511 - MCC   N170 - MCC    K766 - CC    D62 - CC        E119
# 1    A419 - MCC   J869 - MCC    J948 - CC  C7951 - CC   J910 - CC
# 2    J159 - MCC  G9341 - MCC    J440 - CC   I130 - CC  I5042 - CC
# 3     N179 - CC    N136 - CC   Z6843 - CC       E1122       E6601
# 4  D61810 - MCC          Z66  G9341 - MCC   N179 - CC  C3490 - CC
#
#          A_DX7       A_DX8      A_DX9       A_DX10 A_DX11       A_DX12  \
# 0        K7682       F1010        I10         E039   Z794        K3189
# 1   F3130 - CC        J439        I10         E782  E8342       F17210
# 2   I4811 - CC  J9611 - CC  I429 - CC  L97222 - CC    Z66  R6520 - MCC
# 3        K8020       G4733       I129         Z466   N181         E785
# 4  R6520 - MCC        J449      N3090         Z720  R0902         E119
#
#    A_DX13  A_DX14  A_DX15 A_DX16  A_DX17  A_DX18  A_DX19 A_DX20  A_DX21  \
# 0    E785  Z20822  Z87891  Z7984    Z751    Z741   Z7409    NaN     NaN
# 1    Z716    F419    L299   Z170  Z79810    Z853  Z85828  Z9012  Z79811
# 2   E1165   E8342   E1122   N182   E1142  I83002    E785  I2510    K219
# 3  F17220     NaN     NaN    NaN     NaN     NaN     NaN    NaN     NaN
# 4     NaN     NaN     NaN    NaN     NaN     NaN     NaN    NaN     NaN
#
#   A_DX22 A_DX23 A_DX24 A_DX25 A_POA A_POA2 A_POA3 A_POA4 A_POA5 A_POA6 A_POA7  \
# 0    NaN    NaN    NaN    NaN     Y      Y      N      Y      Y      Y      Y
# 1   Z923    NaN    NaN    NaN     Y      Y      Y      Y      Y      Y      Y
# 2   M109  Z8616  Z7901  Z7985     Y      Y      Y      Y      Y      Y      Y
# 3    NaN    NaN    NaN    NaN     Y      Y      Y    NaN      Y      Y      Y
# 4    NaN    NaN    NaN    NaN     Y      Y      Y      Y      Y      Y      Y
#
#   A_POA8 A_POA9 A_POA10 A_POA11 A_POA12 A_POA13 A_POA14 A_POA15 A_POA16  \
# 0      Y      Y       Y               Y       Y       Y
# 1      Y      Y       Y       Y       Y               Y       Y
# 2      Y      Y       Y       Y       Y       Y       Y       Y       Y
# 3      Y      Y     NaN       Y       Y       Y     NaN     NaN     NaN
# 4      Y      Y     NaN       Y       Y     NaN     NaN     NaN     NaN
#
#   A_POA17 A_POA18 A_POA19 A_POA20 A_POA21 A_POA22 A_POA23 A_POA24 A_POA25  \
# 0               Y       Y     NaN     NaN     NaN     NaN     NaN     NaN
# 1                                                     NaN     NaN     NaN
# 2       Y       Y       Y       Y       Y       Y
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      A_PX1    A_PX2    A_PX3    A_PX4    A_PX5 A_PX6 A_PX7 A_PX8 A_PX9 A_PX10  \
# 0  30233N1  06L38CZ  06L38CZ  0BH17EZ  5A1945Z   NaN   NaN   NaN   NaN    NaN
# 1  0W9B30Z  3E03317      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN
# 2  05HY33Z      NaN      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN
# 3  0T748DZ      NaN      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN
# 4      NaN      NaN      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN
#
#   A_PX11 A_PX12 A_PX13 A_PX14 A_PX15 A_PX16 A_PX17 A_PX18 A_PX19 A_PX20  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   A_PX21 A_PX22 A_PX23 A_PX24 A_PX25                       B_DISPCode  \
# 0    NaN    NaN    NaN    NaN    NaN          02-TRNSF ACUTE CARE FAC
# 1    NaN    NaN    NaN    NaN    NaN                  01-ROUTINE/HOME
# 2    NaN    NaN    NaN    NaN    NaN  03-TRNSF TO SKILLED NURSING FAC
# 3    NaN    NaN    NaN    NaN    NaN                  01-ROUTINE/HOME
# 4    NaN    NaN    NaN    NaN    NaN  03-TRNSF TO SKILLED NURSING FAC
#
#   B_DenialCode B_DRG      B_PRIMDX         B_DX2       B_DX3        B_DX4  \
# 0          NaN   432         K7030   I8511 - MCC  N170 - MCC    K766 - CC
# 1          NaN   919  T85698A - CC    A419 - MCC  J869 - MCC    J948 - CC
# 2         801C   194    J159 - MCC     J440 - CC   I130 - CC   I5042 - CC
# 3         801C   660     N136 - CC     N179 - CC  Z6843 - CC        E1122
# 4          NaN   871    A419 - MCC  D61810 - MCC         Z66  G9341 - MCC
#
#         B_DX5       B_DX6        B_DX7        B_DX8  B_DX9 B_DX10 B_DX11  \
# 0    D62 - CC        E119        K7682        F1010    I10   E039   Z794
# 1  C7951 - CC   J910 - CC   F3130 - CC         J439    I10   E782  E8342
# 2  I4811 - CC  J9611 - CC    I429 - CC  L97222 - CC    Z66  E1165  E8342
# 3       E6601       K8020        G4733         I129   Z466   N181   E785
# 4   N179 - CC  C3490 - CC  R6520 - MCC         J449  N3090   Z720  R0902
#
#    B_DX12 B_DX13  B_DX14  B_DX15 B_DX16  B_DX17 B_DX18  B_DX19 B_DX20  B_DX21  \
# 0   K3189   E785  Z20822  Z87891  Z7984    Z751   Z741   Z7409    NaN     NaN
# 1  F17210   Z716    F419    L299   Z170  Z79810   Z853  Z85828  Z9012  Z79811
# 2   E1122   N182   E1142  I83002   E785   I2510   K219    M109  Z8616   Z7901
# 3  F17220    NaN     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4    E119    NaN     NaN     NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
#   B_DX22 B_DX23 B_DX24 B_DX25 B_POA B_POA2 B_POA3 B_POA4 B_POA5 B_POA6 B_POA7  \
# 0    NaN    NaN    NaN    NaN     Y      Y      N      Y      Y      Y      Y
# 1   Z923    NaN    NaN    NaN     Y      Y      Y      Y      Y      Y      Y
# 2  Z7985    NaN    NaN    NaN     Y      Y      Y      Y      Y      Y      Y
# 3    NaN    NaN    NaN    NaN     Y      Y      1      Y      Y      Y      Y
# 4    NaN    NaN    NaN    NaN     Y      Y      Y      Y      Y      Y      Y
#
#   B_POA8 B_POA9 B_POA10 B_POA11 B_POA12 B_POA13 B_POA14 B_POA15 B_POA16  \
# 0      Y      Y       Y     NaN       Y       Y       Y     NaN     NaN
# 1      Y      Y       Y       Y       Y       1       Y       Y       1
# 2      Y      Y       Y       Y       Y       Y       Y       Y       Y
# 3      Y      1       Y       Y       Y     NaN     NaN     NaN     NaN
# 4      Y      Y     NaN       Y       Y     NaN     NaN     NaN     NaN
#
#   B_POA17 B_POA18 B_POA19 B_POA20 B_POA21 B_POA22 B_POA23 B_POA24 B_POA25  \
# 0     NaN       Y       Y     NaN     NaN     NaN     NaN     NaN     NaN
# 1       1       1       1       1       1       1     NaN     NaN     NaN
# 2       Y       Y       Y       1       1       1     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      B_PX1    B_PX2    B_PX3    B_PX4    B_PX5 B_PX6 B_PX7 B_PX8 B_PX9 B_PX10  \
# 0  30233N1  06L38CZ  06L38CZ  0BH17EZ  5A1945Z   NaN   NaN   NaN   NaN    NaN
# 1  0W9B30Z  3E03317      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN
# 2  05HY33Z      NaN      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN
# 3  0T748DZ      NaN      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN
# 4      NaN      NaN      NaN      NaN      NaN   NaN   NaN   NaN   NaN    NaN
#
#   B_PX11 B_PX12 B_PX13 B_PX14 B_PX15 B_PX16 B_PX17 B_PX18 B_PX19 B_PX20  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   B_PX21 B_PX22 B_PX23 B_PX24 B_PX25  \
# 0    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN    NaN
#
#                                                                                                           A_PRIMDX_Desc  \
# 0                                                                          Alcoholic cirrhosis of liver without ascites
# 1  Other mechanical complication of other specified internal prosthetic devices, implants and grafts, initial encounter
# 2                                                                                          Sepsis, unspecified organism
# 3                                                                                          Sepsis, unspecified organism
# 4                                                                                          Sepsis, unspecified organism
#
#                                          A_DX2_Desc  \
# 0        Secondary esophageal varices with bleeding
# 1                      Sepsis, unspecified organism
# 2                   Unspecified bacterial pneumonia
# 3                 Acute kidney failure, unspecified
# 4  Antineoplastic chemotherapy induced pancytopenia
#
#                                    A_DX3_Desc  \
# 0  Acute kidney failure with tubular necrosis
# 1                   Pyothorax without fistula
# 2                    Metabolic encephalopathy
# 3                                Pyonephrosis
# 4                          Do not resuscitate
#
#                                                                        A_DX4_Desc  \
# 0                                                             Portal hypertension
# 1                                              Other specified pleural conditions
# 2  Chronic obstructive pulmonary disease with (acute) lower respiratory infection
# 3                                          Body mass index [BMI] 50.0-59.9, adult
# 4                                                        Metabolic encephalopathy
#
#                                                                                                                                                    A_DX5_Desc  \
# 0                                                                                                                                Acute posthemorrhagic anemia
# 1                                                                                                                        Secondary malignant neoplasm of bone
# 2  Hypertensive heart and chronic kidney disease with heart failure and stage 1 through stage 4 chronic kidney disease, or unspecified chronic kidney disease
# 3                                                                                               Type 2 diabetes mellitus with diabetic chronic kidney disease
# 4                                                                                                                           Acute kidney failure, unspecified
#
#                                                                         A_DX6_Desc  \
# 0                                   Type 2 diabetes mellitus without complications
# 1                                                       Malignant pleural effusion
# 2  Chronic combined systolic (congestive) and diastolic (congestive) heart failure
# 3                                   Morbid (severe) obesity due to excess calories
# 4           Malignant neoplasm of unspecified part of unspecified bronchus or lung
#
#                                                                             A_DX7_Desc  \
# 0                                                               Hepatic encephalopathy
# 1  Bipolar disorder, current episode depressed, mild or moderate severity, unspecified
# 2                                          Longstanding persistent atrial fibrillation
# 3                    Calculus of gallbladder without cholecystitis without obstruction
# 4                                                   Severe sepsis without septic shock
#
#                                            A_DX8_Desc  \
# 0                        Alcohol abuse, uncomplicated
# 1                              Emphysema, unspecified
# 2            Chronic respiratory failure with hypoxia
# 3         Obstructive sleep apnea (adult) (pediatric)
# 4  Chronic obstructive pulmonary disease, unspecified
#
#                                                                                                                        A_DX9_Desc  \
# 0                                                                                                Essential (primary) hypertension
# 1                                                                                                Essential (primary) hypertension
# 2                                                                                                     Cardiomyopathy, unspecified
# 3  Hypertensive chronic kidney disease with stage 1 through stage 4 chronic kidney disease, or unspecified chronic kidney disease
# 4                                                                                         Cystitis, unspecified without hematuria
#
#                                                       A_DX10_Desc  \
# 0                                     Hypothyroidism, unspecified
# 1                                            Mixed hyperlipidemia
# 2  Non-pressure chronic ulcer of left calf with fat layer exposed
# 3          Encounter for fitting and adjustment of urinary device
# 4                                                     Tobacco use
#
#                           A_DX11_Desc  \
# 0  Long term (current) use of insulin
# 1                      Hypomagnesemia
# 2                  Do not resuscitate
# 3     Chronic kidney disease, stage 1
# 4                           Hypoxemia
#
#                                       A_DX12_Desc  \
# 0          Other diseases of stomach and duodenum
# 1  Nicotine dependence, cigarettes, uncomplicated
# 2              Severe sepsis without septic shock
# 3                     Hyperlipidemia, unspecified
# 4  Type 2 diabetes mellitus without complications
#
#                                            A_DX13_Desc  \
# 0                          Hyperlipidemia, unspecified
# 1                             Tobacco abuse counseling
# 2          Type 2 diabetes mellitus with hyperglycemia
# 3  Nicotine dependence, chewing tobacco, uncomplicated
# 4                                                  NaN
#
#                                          A_DX14_Desc  \
# 0  Contact with and (suspected) exposure to COVID-19
# 1                      Anxiety disorder, unspecified
# 2                                     Hypomagnesemia
# 3                                                NaN
# 4                                                NaN
#
#                                                      A_DX15_Desc  \
# 0                        Personal history of nicotine dependence
# 1                                          Pruritus, unspecified
# 2  Type 2 diabetes mellitus with diabetic chronic kidney disease
# 3                                                            NaN
# 4                                                            NaN
#
#                                           A_DX16_Desc  \
# 0  Long term (current) use of oral hypoglycemic drugs
# 1             Estrogen receptor positive status [ER+]
# 2              Chronic kidney disease, stage 2 (mild)
# 3                                                 NaN
# 4                                                 NaN
#
#                                                                  A_DX17_Desc  \
# 0                   Person awaiting admission to adequate facility elsewhere
# 1  Long term (current) use of selective estrogen receptor modulators (SERMs)
# 2                      Type 2 diabetes mellitus with diabetic polyneuropathy
# 3                                                                        NaN
# 4                                                                        NaN
#
#                                                         A_DX18_Desc  \
# 0                            Need for assistance with personal care
# 1                  Personal history of malignant neoplasm of breast
# 2  Varicose veins of unspecified lower extremity with ulcer of calf
# 3                                                               NaN
# 4                                                               NaN
#
#                                             A_DX19_Desc  \
# 0                                Other reduced mobility
# 1  Personal history of other malignant neoplasm of skin
# 2                           Hyperlipidemia, unspecified
# 3                                                   NaN
# 4                                                   NaN
#
#                                                                        A_DX20_Desc  \
# 0                                                                              NaN
# 1                                       Acquired absence of left breast and nipple
# 2  Atherosclerotic heart disease of native coronary artery without angina pectoris
# 3                                                                              NaN
# 4                                                                              NaN
#
#                                             A_DX21_Desc  \
# 0                                                   NaN
# 1       Long term (current) use of aromatase inhibitors
# 2  Gastro-esophageal reflux disease without esophagitis
# 3                                                   NaN
# 4                                                   NaN
#
#                        A_DX22_Desc                   A_DX23_Desc  \
# 0                              NaN                           NaN
# 1  Personal history of irradiation                           NaN
# 2                Gout, unspecified  Personal history of COVID-19
# 3                              NaN                           NaN
# 4                              NaN                           NaN
#
#                                  A_DX24_Desc  \
# 0                                        NaN
# 1                                        NaN
# 2  Long term (current) use of anticoagulants
# 3                                        NaN
# 4                                        NaN
#
#                                                   A_DX25_Desc  \
# 0                                                         NaN
# 1                                                         NaN
# 2  Lng trm(crnt)use injectable non-insulin antidiabetic drugs
# 3                                                         NaN
# 4                                                         NaN
#
#                                                                                               A_PX1_Desc  \
# 0               Transfusion of Nonautologous Red Blood Cells into Peripheral Vein, Percutaneous Approach
# 1                            Drainage of Left Pleural Cavity with Drainage Device, Percutaneous Approach
# 2                                    Insertion of Infusion Device into Upper Vein, Percutaneous Approach
# 3  Dilation of Left Kidney Pelvis with Intraluminal Device, Via Natural or Artificial Opening Endoscopic
# 4                                                                                                    NaN
#
#                                                                                             A_PX2_Desc  \
# 0  Occlusion of Esophageal Vein with Extraluminal Device, Via Natural or Artificial Opening Endoscopic
# 1                       Introduction of Other Thrombolytic into Peripheral Vein, Percutaneous Approach
# 2                                                                                                  NaN
# 3                                                                                                  NaN
# 4                                                                                                  NaN
#
#                                                                                             A_PX3_Desc  \
# 0  Occlusion of Esophageal Vein with Extraluminal Device, Via Natural or Artificial Opening Endoscopic
# 1                                                                                                  NaN
# 2                                                                                                  NaN
# 3                                                                                                  NaN
# 4                                                                                                  NaN
#
#                                                                          A_PX4_Desc  \
# 0  Insertion of Endotracheal Airway into Trachea, Via Natural or Artificial Opening
# 1                                                                               NaN
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
#
#                                          A_PX5_Desc A_PX6_Desc A_PX7_Desc  \
# 0  Respiratory Ventilation, 24-96 Consecutive Hours        NaN        NaN
# 1                                               NaN        NaN        NaN
# 2                                               NaN        NaN        NaN
# 3                                               NaN        NaN        NaN
# 4                                               NaN        NaN        NaN
#
#   A_PX8_Desc A_PX9_Desc A_PX10_Desc A_PX11_Desc A_PX12_Desc A_PX13_Desc  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
# 2        NaN        NaN         NaN         NaN         NaN         NaN
# 3        NaN        NaN         NaN         NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN         NaN         NaN
#
#   A_PX14_Desc A_PX15_Desc A_PX16_Desc A_PX17_Desc A_PX18_Desc A_PX19_Desc  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   A_PX20_Desc A_PX21_Desc A_PX22_Desc A_PX23_Desc A_PX24_Desc A_PX25_Desc  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#                                                                                                           B_PRIMDX_Desc  \
# 0                                                                          Alcoholic cirrhosis of liver without ascites
# 1  Other mechanical complication of other specified internal prosthetic devices, implants and grafts, initial encounter
# 2                                                                                       Unspecified bacterial pneumonia
# 3                                                                                                          Pyonephrosis
# 4                                                                                          Sepsis, unspecified organism
#
#                                                                        B_DX2_Desc  \
# 0                                      Secondary esophageal varices with bleeding
# 1                                                    Sepsis, unspecified organism
# 2  Chronic obstructive pulmonary disease with (acute) lower respiratory infection
# 3                                               Acute kidney failure, unspecified
# 4                                Antineoplastic chemotherapy induced pancytopenia
#
#                                                                                                                                                    B_DX3_Desc  \
# 0                                                                                                                  Acute kidney failure with tubular necrosis
# 1                                                                                                                                   Pyothorax without fistula
# 2  Hypertensive heart and chronic kidney disease with heart failure and stage 1 through stage 4 chronic kidney disease, or unspecified chronic kidney disease
# 3                                                                                                                      Body mass index [BMI] 50.0-59.9, adult
# 4                                                                                                                                          Do not resuscitate
#
#                                                                         B_DX4_Desc  \
# 0                                                              Portal hypertension
# 1                                               Other specified pleural conditions
# 2  Chronic combined systolic (congestive) and diastolic (congestive) heart failure
# 3                    Type 2 diabetes mellitus with diabetic chronic kidney disease
# 4                                                         Metabolic encephalopathy
#
#                                        B_DX5_Desc  \
# 0                    Acute posthemorrhagic anemia
# 1            Secondary malignant neoplasm of bone
# 2     Longstanding persistent atrial fibrillation
# 3  Morbid (severe) obesity due to excess calories
# 4               Acute kidney failure, unspecified
#
#                                                                B_DX6_Desc  \
# 0                          Type 2 diabetes mellitus without complications
# 1                                              Malignant pleural effusion
# 2                                Chronic respiratory failure with hypoxia
# 3       Calculus of gallbladder without cholecystitis without obstruction
# 4  Malignant neoplasm of unspecified part of unspecified bronchus or lung
#
#                                                                             B_DX7_Desc  \
# 0                                                               Hepatic encephalopathy
# 1  Bipolar disorder, current episode depressed, mild or moderate severity, unspecified
# 2                                                          Cardiomyopathy, unspecified
# 3                                          Obstructive sleep apnea (adult) (pediatric)
# 4                                                   Severe sepsis without septic shock
#
#                                                                                                                        B_DX8_Desc  \
# 0                                                                                                    Alcohol abuse, uncomplicated
# 1                                                                                                          Emphysema, unspecified
# 2                                                                  Non-pressure chronic ulcer of left calf with fat layer exposed
# 3  Hypertensive chronic kidney disease with stage 1 through stage 4 chronic kidney disease, or unspecified chronic kidney disease
# 4                                                                              Chronic obstructive pulmonary disease, unspecified
#
#                                                B_DX9_Desc  \
# 0                        Essential (primary) hypertension
# 1                        Essential (primary) hypertension
# 2                                      Do not resuscitate
# 3  Encounter for fitting and adjustment of urinary device
# 4                 Cystitis, unspecified without hematuria
#
#                                    B_DX10_Desc  \
# 0                  Hypothyroidism, unspecified
# 1                         Mixed hyperlipidemia
# 2  Type 2 diabetes mellitus with hyperglycemia
# 3              Chronic kidney disease, stage 1
# 4                                  Tobacco use
#
#                           B_DX11_Desc  \
# 0  Long term (current) use of insulin
# 1                      Hypomagnesemia
# 2                      Hypomagnesemia
# 3         Hyperlipidemia, unspecified
# 4                           Hypoxemia
#
#                                                      B_DX12_Desc  \
# 0                         Other diseases of stomach and duodenum
# 1                 Nicotine dependence, cigarettes, uncomplicated
# 2  Type 2 diabetes mellitus with diabetic chronic kidney disease
# 3            Nicotine dependence, chewing tobacco, uncomplicated
# 4                 Type 2 diabetes mellitus without complications
#
#                               B_DX13_Desc  \
# 0             Hyperlipidemia, unspecified
# 1                Tobacco abuse counseling
# 2  Chronic kidney disease, stage 2 (mild)
# 3                                     NaN
# 4                                     NaN
#
#                                              B_DX14_Desc  \
# 0      Contact with and (suspected) exposure to COVID-19
# 1                          Anxiety disorder, unspecified
# 2  Type 2 diabetes mellitus with diabetic polyneuropathy
# 3                                                    NaN
# 4                                                    NaN
#
#                                                         B_DX15_Desc  \
# 0                           Personal history of nicotine dependence
# 1                                             Pruritus, unspecified
# 2  Varicose veins of unspecified lower extremity with ulcer of calf
# 3                                                               NaN
# 4                                                               NaN
#
#                                           B_DX16_Desc  \
# 0  Long term (current) use of oral hypoglycemic drugs
# 1             Estrogen receptor positive status [ER+]
# 2                         Hyperlipidemia, unspecified
# 3                                                 NaN
# 4                                                 NaN
#
#                                                                        B_DX17_Desc  \
# 0                         Person awaiting admission to adequate facility elsewhere
# 1        Long term (current) use of selective estrogen receptor modulators (SERMs)
# 2  Atherosclerotic heart disease of native coronary artery without angina pectoris
# 3                                                                              NaN
# 4                                                                              NaN
#
#                                             B_DX18_Desc  \
# 0                Need for assistance with personal care
# 1      Personal history of malignant neoplasm of breast
# 2  Gastro-esophageal reflux disease without esophagitis
# 3                                                   NaN
# 4                                                   NaN
#
#                                             B_DX19_Desc  \
# 0                                Other reduced mobility
# 1  Personal history of other malignant neoplasm of skin
# 2                                     Gout, unspecified
# 3                                                   NaN
# 4                                                   NaN
#
#                                   B_DX20_Desc  \
# 0                                         NaN
# 1  Acquired absence of left breast and nipple
# 2                Personal history of COVID-19
# 3                                         NaN
# 4                                         NaN
#
#                                        B_DX21_Desc  \
# 0                                              NaN
# 1  Long term (current) use of aromatase inhibitors
# 2        Long term (current) use of anticoagulants
# 3                                              NaN
# 4                                              NaN
#
#                                                   B_DX22_Desc B_DX23_Desc  \
# 0                                                         NaN         NaN
# 1                             Personal history of irradiation         NaN
# 2  Lng trm(crnt)use injectable non-insulin antidiabetic drugs         NaN
# 3                                                         NaN         NaN
# 4                                                         NaN         NaN
#
#   B_DX24_Desc B_DX25_Desc  \
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
#                                                                                               B_PX1_Desc  \
# 0               Transfusion of Nonautologous Red Blood Cells into Peripheral Vein, Percutaneous Approach
# 1                            Drainage of Left Pleural Cavity with Drainage Device, Percutaneous Approach
# 2                                    Insertion of Infusion Device into Upper Vein, Percutaneous Approach
# 3  Dilation of Left Kidney Pelvis with Intraluminal Device, Via Natural or Artificial Opening Endoscopic
# 4                                                                                                    NaN
#
#                                                                                             B_PX2_Desc  \
# 0  Occlusion of Esophageal Vein with Extraluminal Device, Via Natural or Artificial Opening Endoscopic
# 1                       Introduction of Other Thrombolytic into Peripheral Vein, Percutaneous Approach
# 2                                                                                                  NaN
# 3                                                                                                  NaN
# 4                                                                                                  NaN
#
#                                                                                             B_PX3_Desc  \
# 0  Occlusion of Esophageal Vein with Extraluminal Device, Via Natural or Artificial Opening Endoscopic
# 1                                                                                                  NaN
# 2                                                                                                  NaN
# 3                                                                                                  NaN
# 4                                                                                                  NaN
#
#                                                                          B_PX4_Desc  \
# 0  Insertion of Endotracheal Airway into Trachea, Via Natural or Artificial Opening
# 1                                                                               NaN
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
#
#                                          B_PX5_Desc B_PX6_Desc B_PX7_Desc  \
# 0  Respiratory Ventilation, 24-96 Consecutive Hours        NaN        NaN
# 1                                               NaN        NaN        NaN
# 2                                               NaN        NaN        NaN
# 3                                               NaN        NaN        NaN
# 4                                               NaN        NaN        NaN
#
#   B_PX8_Desc B_PX9_Desc B_PX10_Desc B_PX11_Desc B_PX12_Desc B_PX13_Desc  \
# 0        NaN        NaN         NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN         NaN
# 2        NaN        NaN         NaN         NaN         NaN         NaN
# 3        NaN        NaN         NaN         NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN         NaN         NaN
#
#   B_PX14_Desc B_PX15_Desc B_PX16_Desc B_PX17_Desc B_PX18_Desc B_PX19_Desc  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   B_PX20_Desc B_PX21_Desc B_PX22_Desc B_PX23_Desc B_PX24_Desc B_PX25_Desc  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#         InitialDeterminationDate InitialDenialType InitialDeterminationStatus  \
# 0  2023-11-17 13:25:52.370000000       Substantive                   Approved
# 1  2023-11-02 10:37:06.710000000       Substantive                   Approved
# 2  2024-01-03 14:38:45.370000000       Substantive                     Denied
# 3  2022-02-01 11:22:02.580000000       Substantive                     Denied
# 4  2022-01-31 08:47:15.543000000       Substantive                   Approved
#
#   IDSavings     AdjustedSavings
# 0       .00                   0
# 1       .00                   0
# 2   4440.18  5940.3100000000004
# 3   3065.19  2733.5700000000002
# 4       .00                   0

# %%
print(df_hist['InitialDenialType'].value_counts())
# Out:
# InitialDenialType
# Substantive    772104
# Assumptive     110464
# Technical        3524
# Name: count, dtype: int64

# %%
df_hist_sub = df_hist[df_hist['InitialDenialType']=='Substantive'].copy()
df_hist_sub.shape
# Out:
# (772104, 282)

# %%
df_hist_sub_hum = df_hist_sub[df_hist_sub['Client']=='Hum'].copy()
df_hist_sub_hum.shape
# Out:
# (64924, 282)

# %%
df_hist_sub_hum['len_adrg'] = df_hist_sub_hum['ADRG'].astype(str).str.len()
df_hist_sub_hum['len_bdrg'] = df_hist_sub_hum['B_DRG'].astype(str).str.len()

# %%
df_hist_sub_hum['len_adrg'].value_counts()
# Out:
# len_adrg
# 3    64064
# 4      860
# Name: count, dtype: int64

# %%
df_hist_sub_hum['InitialDeterminationStatus'].value_counts()
# Out:
# InitialDeterminationStatus
# Approved    56906
# Denied       8018
# Name: count, dtype: int64

# %%
df_hist_sub_hum_ms_drg = df_hist_sub_hum[~(df_hist_sub_hum['len_adrg']==4)].copy()
df_hist_sub_hum_ms_drg.shape
# Out:
# (64064, 284)

# %%
df_hist_sub_hum_ms_drg["AGE"] = pd.to_numeric(df_hist_sub_hum_ms_drg["AGE"], errors="coerce")
df_hist_sub_hum_ms_drg_age = df_hist_sub_hum_ms_drg[df_hist_sub_hum_ms_drg['AGE'] > 0]
df_hist_sub_hum_ms_drg_age.shape
# Out:
# (64063, 284)

# %%
df_hist_sub_hum_ms_drg_age['LOS'] = (
    df_hist_sub_hum_ms_drg_age['LOS']
        .astype(str)            # convert to string
        .str.strip()            # remove spaces
        .replace('', pd.NA)     # replace '' with NaN
        .astype('float')        # convert safely
        .astype('Int64')        # convert to integer (nullable)
)

df_hist_sub_hum_ms_drg_age_los = df_hist_sub_hum_ms_drg_age[df_hist_sub_hum_ms_drg_age['LOS'] >=0]
df_hist_sub_hum_ms_drg_age_los.shape
# Out:
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\1772071357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age['LOS'] = (
# (64061, 284)

# %%
# Step 1: Normalize DRG and A_PDX
df_hist_sub_hum_ms_drg_age_los['ADRG'] =df_hist_sub_hum_ms_drg_age_los['ADRG'].astype(str).str.strip()
df_hist_sub_hum_ms_drg_age_los['PRIM_DX'] = df_hist_sub_hum_ms_drg_age_los['PRIM_DX'].astype(str).str.strip().str.upper()
df_hist_sub_hum_ms_drg_age_los['LOB'] = df_hist_sub_hum_ms_drg_age_los['LOB'].astype(str).str.strip().str.upper()
df_hist_sub_hum_ms_drg_age_los['PaymentType'] = df_hist_sub_hum_ms_drg_age_los['PaymentType'].str.strip().str.upper()

# Step 2: Ensure numeric fields are clean

df_hist_sub_hum_ms_drg_age_los['IDSavings'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['IDSavings'], errors='coerce').fillna(0)
df_hist_sub_hum_ms_drg_age_los['LOS'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['LOS'], errors='coerce').fillna(0)
df_hist_sub_hum_ms_drg_age_los['AGE'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['AGE'], errors='coerce').fillna(0)
df_hist_sub_hum_ms_drg_age_los['A_MCCCount'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['A_MCCCount'], errors='coerce').fillna(0).astype(int)
df_hist_sub_hum_ms_drg_age_los['A_CCCount'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['A_CCCount'], errors='coerce').fillna(0).astype(int)
# Out:
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\172421177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age_los['ADRG'] =df_hist_sub_hum_ms_drg_age_los['ADRG'].astype(str).str.strip()
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\172421177.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age_los['PRIM_DX'] = df_hist_sub_hum_ms_drg_age_los['PRIM_DX'].astype(str).str.strip().str.upper()
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\172421177.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age_los['LOB'] = df_hist_sub_hum_ms_drg_age_los['LOB'].astype(str).str.strip().str.upper()
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\172421177.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age_los['PaymentType'] = df_hist_sub_hum_ms_drg_age_los['PaymentType'].str.strip().str.upper()
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\172421177.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age_los['IDSavings'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['IDSavings'], errors='coerce').fillna(0)
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\172421177.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age_los['LOS'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['LOS'], errors='coerce').fillna(0)
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\172421177.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age_los['AGE'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['AGE'], errors='coerce').fillna(0)
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\172421177.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age_los['A_MCCCount'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['A_MCCCount'], errors='coerce').fillna(0).astype(int)
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\172421177.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hist_sub_hum_ms_drg_age_los['A_CCCount'] = pd.to_numeric(df_hist_sub_hum_ms_drg_age_los['A_CCCount'], errors='coerce').fillna(0).astype(int)

# %%
df_hist_sub_hum_ms_drg_age_los['InitialDeterminationStatus'].value_counts()
# Out:
# InitialDeterminationStatus
# Approved    56119
# Denied       7942
# Name: count, dtype: int64

# %%
df1 = df_hist_sub_hum_ms_drg_age_los.copy()

adx_cols = [f"A_DX{i}" for i in range(2, 26)]
apx_cols = [f"A_PX{i}" for i in range(1, 26)]
#bdx_cols = [f"B_DX{i}" for i in range(2, 26)]
#bpx_cols = [f"B_PX{i}" for i in range(1, 26)]

df1["A_DX_List"] = df1[adx_cols].values.tolist()
df1["A_PX_List"] = df1[apx_cols].values.tolist()
#df1["B_DX_List"] = df1[bdx_cols].values.tolist()
#df1["B_PX_List"] = df1[bpx_cols].values.tolist()

df1["A_DX_List"] = df1["A_DX_List"].apply(lambda x: tuple(sorted([i for i in x if pd.notna(i)])))
df1["A_PX_List"] = df1["A_PX_List"].apply(lambda x: tuple(sorted([i for i in x if pd.notna(i)])))
#df1["B_DX_List"] = df1["B_DX_List"].apply(lambda x: tuple(sorted([i for i in x if pd.notna(i)])))
#df1["B_PX_List"] = df1["B_PX_List"].apply(lambda x: tuple(sorted([i for i in x if pd.notna(i)])))

df2 = df1.copy()

def clean_sdx_list(lst):
    cleaned = []
    for item in lst:
        item = str(item).upper().strip()               # normalize
        item = item.replace("- MCC", "")               # remove MCC
        item = item.replace("- CC", "")                # remove CC
        item = item.replace("MCC", "")                 # safety
        item = item.replace("CC", "")                  # safety
        cleaned.append(item.strip().replace("-", ""))  # final cleanup
    return tuple(cleaned)  # convert to tuple

df2["A_DX_List_Clean"] = df2["A_DX_List"].apply(clean_sdx_list)
#df2["B_DX_List_Clean"] = df2["B_DX_List"].apply(clean_sdx_list)

mccandcclist_df = pd.read_excel(r"C:\Users\Arunkumara\Downloads\MCCCCList (1).xlsx")
mccandcclist_df['ICDCode'] = (
    mccandcclist_df['ICDCode']
    .astype(str)
    .str.strip()
    .str.upper()
)
mccandcclist = dict(zip(mccandcclist_df['ICDCode'], mccandcclist_df['MCCorCC']))

def map_sdx_types(icd_list, lookup_dict):
    cleaned_list = []
    for code in icd_list:
        code_clean = str(code).strip().upper()  # normalize

        tag = lookup_dict.get(code_clean, "")  # MCC / CC / General
        cleaned_list.append(f"{code_clean} - {tag}")

    return tuple(cleaned_list)   # convert to tuple

df2['A_DX_Type_list'] = df2['A_DX_List_Clean'].apply(lambda x: map_sdx_types(x, mccandcclist))
#df2['B_DX_Type_list'] = df2['B_DX_List_Clean'].apply(lambda x: map_sdx_types(x, mccandcclist))

def split_px_list(px_list):
    mcc = []
    cc = []
    general = []
    
    for item in px_list:
        parts = item.split('-')
        code = parts[0].strip()
        flag = parts[1].strip() if len(parts) > 1 else ""
        
        if flag == "MCC":
            mcc.append(code)
        elif flag == "CC":
            cc.append(code)
        else:
            general.append(code)
    
    return tuple(mcc), tuple(cc), tuple(general)   # convert to tuple

df2["A_MCC_List"], df2["A_CC_List"], df2["A_General_List"] = zip(*df2["A_DX_Type_list"].apply(split_px_list))
#df2["B_MCC_List"], df2["B_CC_List"], df2["B_General_List"] = zip(*df2["B_DX_Type_list"].apply(split_px_list))

def extract_sdx_info(sdx_list):

    # If list/tuple is empty → return
    if not sdx_list:
        return "No MCC or CC", tuple()

    # Separate entries by type
    mcc = [x.split(" - ")[0] for x in sdx_list if "- MCC" in x]
    cc  = [x.split(" - ")[0] for x in sdx_list if "- CC" in x]
    other = [
        x.split(" - ")[0]
        for x in sdx_list 
        if "- MCC" not in x and "- CC" not in x
    ]

    # Determine type and return tuple
    if mcc:
        return "MCC", tuple(mcc)
    elif cc:
        return "CC", tuple(cc)
    elif other:
        return "No MCC or CC", tuple(other)
    else:
        return "No MCC or CC", tuple()

df2[["A_DX_Type", "A_DX_Set"]] = df2["A_DX_List"].apply(
    lambda x: pd.Series(extract_sdx_info(x))
)


df2['SDX Set'] = df2.apply(
    lambda x: "No MCC or CC" if x['A_DX_Type'] == 'No MCC or CC' else x['A_DX_Set'],
    axis=1
)



#df2[["B_DX_Type", "B_DX_Set"]] = df2["B_DX_List"].apply(
 #   lambda x: pd.Series(extract_sdx_info(x))
#)

# %%
df2['A_DX_Type'].unique()
# Out:
# array(['MCC', 'CC', 'No MCC or CC'], dtype=object)

# %%
df2['ADRG'].unique().shape
# Out:
# (604,)

# %%
from functools import reduce

common_px_by_adrg = (
    df2
    .groupby('ADRG')['A_PX_List']
    .apply(lambda x: list(reduce(set.intersection, map(set, x))) if len(x) > 1 else [])
    .reset_index(name='Common_PX')
)

#common_px_by_adrg = common_px_by_adrg[common_px_by_adrg['Common_PX'].str.len() > 0]
common_px_by_adrg.shape
# Out:
# (604, 2)

# %%
df2 = df2.merge(common_px_by_adrg,how = 'left',on = 'ADRG')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64061 entries, 0 to 64060
# Columns: 295 entries, Payor to Common_PX
# dtypes: Int64(1), float64(1), int64(5), object(288)
# memory usage: 144.2+ MB

# %%
columns_to_keep = [
    "Payor","claimid","Client","Control_ID","Claim_Number","PaymentType","Group_Type","Payments",
    "Tax_ID","Provider_ID","HospitalName","LOS","DischargeYear","DischargeMonth","AGE",
    "LOB","MRREQ","MRREC","DISP_Code","ADRG","PRIM_DX","A_DX_List","A_PX_List","A_DX_List_Clean",
   "A_DX_Type_list","A_MCC_List","A_CC_List",
    "A_General_List","A_DX_Type", "A_DX_Set","SDX Set","Common_PX",
    "InitialDeterminationDate","InitialDenialType",
    "InitialDeterminationStatus","IDSavings","AdjustedSavings"
]

df_clean = df2[columns_to_keep].copy()
df_clean.head()
# Out:
#    Payor claimid Client    Control_ID     Claim_Number PaymentType Group_Type  \
# 0  Strat  791310    Hum  HUPTMR-19212  820232690715794     POSTPAY         01
# 1  Strat  818676    Hum  HUPTMR-23423  820233110206416     POSTPAY         01
# 2  Strat  819586    Hum  HUPTMR-22976  820231970020992     POSTPAY         01
# 3  Strat  832168    Hum  HUPTMR-24604  820232340355670     POSTPAY         01
# 4  Strat  832171    Hum  HUPTMR-24728  820232220351457     POSTPAY         01
#
#              Payments     Tax_ID Provider_ID                    HospitalName  \
# 0  7815.4300000000003  560554230  000045770H  NOVANT HEALTH PRESBYTERIAN MED
# 1  15539.610000000001  576000934  001825011C  SPARTANBURG REGIONAL MEDICAL C
# 2             9020.75  381428164   381428164                 MCLAREN OAKLAND
# 3            14704.33  853777599  853777599B  NOVANT NEW HANOVER REGIONAL ME
# 4  10356.879999999999  853777599  853777599B  NOVANT NEW HANOVER REGIONAL ME
#
#    LOS DischargeYear DischargeMonth  AGE    LOB                MRREQ  \
# 0    9          2023              9   76  MRO39  2023-12-13 00:00:00
# 1   16          2023             11   63  MEP3I  2024-02-13 00:00:00
# 2    7          2023              7   79  MER32  2024-02-13 00:00:00
# 3   17          2023              7   69  MEP3I  2024-03-05 00:00:00
# 4   14          2023              7   79  MGP3I  2024-03-05 00:00:00
#
#                  MRREC                        DISP_Code ADRG PRIM_DX  \
# 0  2024-04-16 00:00:00          06-TRNSF TO HOME HEALTH  189   J9601
# 1  2024-04-16 00:00:00   63-TRNSF TO LONG TERM CARE FAC  539   M4626
# 2  2024-04-16 00:00:00                  01-ROUTINE/HOME  682    I120
# 3  2024-04-17 00:00:00  03-TRNSF TO SKILLED NURSING FAC  064   I6340
# 4  2024-04-16 00:00:00  03-TRNSF TO SKILLED NURSING FAC  391   K5720
#
#                                                                                                                                                                                                                A_DX_List  \
# 0                                          (C3491 - CC, C7951 - CC, E1110 - MCC, E1165, E46 - CC, I2609 - MCC, I5022 - CC, I5023 - MCC, J432, J9602 - MCC, J9611 - CC, R042 - CC, R64 - CC, R7401, Z66, Z681 - CC, Z720)
# 1                                                                   (B9562, E785, G061 - MCC, G629, G8929, H9190, I10, K6812 - MCC, M0579, M4646, R5381, R7881 - CC, Z5986, Z79631, Z8614, Z8661, Z86718, Z8673, Z87891)
# 2                                                                     (C787 - CC, C7951 - CC, D631, E1122, E1165, F17210, I161 - CC, J90 - CC, K7210, K7682, K8020, N186 - MCC, R112, R5381, Z7901, Z79899, Z8673, Z992)
# 3  (B1920, B9561, D649, E43 - MCC, E861, E8720 - CC, F0154 - CC, F17200, F1910, G319, G910 - CC, G9341 - MCC, I110, I5032 - CC, I76 - CC, M6282 - CC, N179 - CC, N390 - CC, R1310, R32, R64 - CC, R7881 - CC, Z681 - CC)
# 4                             (E43 - MCC, E8729 - CC, I10, J439, J90 - CC, J9621 - MCC, J9622 - MCC, J9811 - CC, K219, K632 - CC, K651 - MCC, Z6822, Z713, Z7951, Z7952, Z79899, Z85118, Z853, Z87891, Z881, Z888, Z923)
#
#                      A_PX_List  \
# 0                   (5A09357,)
# 1  (02HV33Z, 0K9N3ZZ, 0Q903ZZ)
# 2                   (5A1D70Z,)
# 3           (02HV33Z, B246ZZ4)
# 4                   (0W993ZZ,)
#
#                                                                                                                                       A_DX_List_Clean  \
# 0                                       (C3491, C7951, E1110, E1165, E46, I2609, I5022, I5023, J432, J9602, J9611, R042, R64, R7401, Z66, Z681, Z720)
# 1                 (B9562, E785, G061, G629, G8929, H9190, I10, K6812, M0579, M4646, R5381, R7881, Z5986, Z79631, Z8614, Z8661, Z86718, Z8673, Z87891)
# 2                            (C787, C7951, D631, E1122, E1165, F17210, I161, J90, K7210, K7682, K8020, N186, R112, R5381, Z7901, Z79899, Z8673, Z992)
# 3  (B1920, B9561, D649, E43, E861, E8720, F0154, F17200, F1910, G319, G910, G9341, I110, I5032, I76, M6282, N179, N390, R1310, R32, R64, R7881, Z681)
# 4      (E43, E8729, I10, J439, J90, J9621, J9622, J9811, K219, K632, K651, Z6822, Z713, Z7951, Z7952, Z79899, Z85118, Z853, Z87891, Z881, Z888, Z923)
#
#                                                                                                                                                                                                                                     A_DX_Type_list  \
# 0                                                     (C3491 - CC, C7951 - CC, E1110 - MCC, E1165 - , E46 - CC, I2609 - MCC, I5022 - CC, I5023 - MCC, J432 - , J9602 - MCC, J9611 - CC, R042 - CC, R64 - CC, R7401 - , Z66 - , Z681 - CC, Z720 - )
# 1                                             (B9562 - , E785 - , G061 - MCC, G629 - , G8929 - , H9190 - , I10 - , K6812 - MCC, M0579 - , M4646 - , R5381 - , R7881 - CC, Z5986 - , Z79631 - , Z8614 - , Z8661 - , Z86718 - , Z8673 - , Z87891 - )
# 2                                                        (C787 - CC, C7951 - CC, D631 - , E1122 - , E1165 - , F17210 - , I161 - CC, J90 - CC, K7210 - , K7682 - , K8020 - , N186 - MCC, R112 - , R5381 - , Z7901 - , Z79899 - , Z8673 - , Z992 - )
# 3  (B1920 - , B9561 - , D649 - , E43 - MCC, E861 - , E8720 - , F0154 - , F17200 - , F1910 - , G319 - , G910 - CC, G9341 - MCC, I110 - , I5032 - CC, I76 - CC, M6282 - CC, N179 - CC, N390 - CC, R1310 - , R32 - , R64 - CC, R7881 - CC, Z681 - CC)
# 4               (E43 - MCC, E8729 - , I10 - , J439 - , J90 - CC, J9621 - MCC, J9622 - MCC, J9811 - CC, K219 - , K632 - CC, K651 - MCC, Z6822 - , Z713 - , Z7951 - , Z7952 - , Z79899 - , Z85118 - , Z853 - , Z87891 - , Z881 - , Z888 - , Z923 - )
#
#                      A_MCC_List  \
# 0  (E1110, I2609, I5023, J9602)
# 1                 (G061, K6812)
# 2                       (N186,)
# 3                  (E43, G9341)
# 4     (E43, J9621, J9622, K651)
#
#                                                  A_CC_List  \
# 0       (C3491, C7951, E46, I5022, J9611, R042, R64, Z681)
# 1                                                 (R7881,)
# 2                                 (C787, C7951, I161, J90)
# 3  (G910, I5032, I76, M6282, N179, N390, R64, R7881, Z681)
# 4                                       (J90, J9811, K632)
#
#                                                                                                     A_General_List  \
# 0                                                                                  (E1165, J432, R7401, Z66, Z720)
# 1  (B9562, E785, G629, G8929, H9190, I10, M0579, M4646, R5381, Z5986, Z79631, Z8614, Z8661, Z86718, Z8673, Z87891)
# 2                       (D631, E1122, E1165, F17210, K7210, K7682, K8020, R112, R5381, Z7901, Z79899, Z8673, Z992)
# 3                                  (B1920, B9561, D649, E861, E8720, F0154, F17200, F1910, G319, I110, R1310, R32)
# 4              (E8729, I10, J439, K219, Z6822, Z713, Z7951, Z7952, Z79899, Z85118, Z853, Z87891, Z881, Z888, Z923)
#
#   A_DX_Type                      A_DX_Set                       SDX Set  \
# 0       MCC  (E1110, I2609, I5023, J9602)  (E1110, I2609, I5023, J9602)
# 1       MCC                 (G061, K6812)                 (G061, K6812)
# 2       MCC                       (N186,)                       (N186,)
# 3       MCC                  (E43, G9341)                  (E43, G9341)
# 4       MCC     (E43, J9621, J9622, K651)     (E43, J9621, J9622, K651)
#
#   Common_PX       InitialDeterminationDate InitialDenialType  \
# 0        []  2024-04-23 03:23:47.970000000       Substantive
# 1        []  2024-04-24 02:41:21.070000000       Substantive
# 2        []  2024-04-23 06:33:12.127000000       Substantive
# 3        []  2024-04-24 02:45:31.550000000       Substantive
# 4        []  2024-04-23 13:31:20.147000000       Substantive
#
#   InitialDeterminationStatus  IDSavings AdjustedSavings
# 0                   Approved        0.0               0
# 1                   Approved        0.0               0
# 2                   Approved        0.0               0
# 3                   Approved        0.0               0
# 4                   Approved        0.0               0

# %%
import pandas as pd

df = df_clean.copy()

# Fix datatype
df["Payments"] = pd.to_numeric(df["Payments"], errors="coerce")
df["IDSavings"] = pd.to_numeric(df["IDSavings"], errors="coerce")

df["SDX Set"] = df["SDX Set"].apply(lambda x: tuple(x) if isinstance(x, list) else x)
df["Common_PX"] = df["Common_PX"].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# 1 Base Aggregation
df_group = df.groupby(["Provider_ID"]).agg(
    tot_claims=("InitialDeterminationStatus", "count"),
    app_count=("InitialDeterminationStatus", lambda x: (x == "Approved").sum()),
    den_count=("InitialDeterminationStatus", lambda x: (x == "Denied").sum()),
    tot_payments=("Payments", "sum"),
    avg_payments=("Payments", "mean"),
    #max_payments=("Payments", "max"),
    #min_payments=("Payments", "min"),
    #count_payments=("Payments", "count")
).reset_index()

# 2 % Denied
df_group["per_app"] = (
    df_group["app_count"] / df_group["tot_claims"] * 100
).round(2)

df_group["per_den"] = (
    df_group["den_count"] / df_group["tot_claims"] * 100
).round(2)

# 3 Denied-only aggregation
denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
    ["Provider_ID"]
).agg(
    den_tot_payments=("Payments", "sum"),
    den_avg_payments=("Payments", "mean"),
    den_avg_saving=("IDSavings", "mean"),
    den_tot_saving=("IDSavings", "sum")
).reset_index()

# 4 Merge
df_group = df_group.merge(denied_stats, on=["Provider_ID"], how="left")

# 5 Sorting
df_group = df_group.sort_values(by="den_count", ascending=False).reset_index(drop=True)

cols = [
    'tot_payments',
    'avg_payments',
    'per_app',
    'per_den',
    'den_tot_payments',
    'den_avg_payments',
    'den_avg_saving',
    'den_tot_saving'
]

df_group[cols] = df_group[cols].round(2)


df_group.to_excel("Hum_Provider.xlsx")
df_group.head(15)
# Out:
#    Provider_ID  tot_claims  app_count  den_count  tot_payments  avg_payments  \
# 0    730700090         185        128         57    2007220.89      10849.84
# 1   000047750D         386        329         57    4854414.02      12576.20
# 2   000059420E         545        490         55    9158973.04      16805.46
# 3   000021832C         405        353         52    4376200.25      10805.43
# 4    560928089         299        256         43    3749187.46      12539.09
# 5    381360584         360        318         42    4628504.64      12856.96
# 6    730657693         213        171         42    2390537.19      11223.18
# 7   853777599B         360        318         42    5758014.44      15994.48
# 8   581123037T         279        241         38    3713370.45      13309.57
# 9   000098152D         176        139         37    2855198.78      16222.72
# 10  566017737F         293        257         36    3925171.03      13396.49
# 11  630845288C         187        152         35    2362977.74      12636.24
# 12  593458145N         273        239         34    4905219.61      17967.84
# 13  582149128A         311        278         33    4147090.88      13334.70
# 14  000190356A         243        210         33    3414692.68      14052.23
#
#     per_app  per_den  den_tot_payments  den_avg_payments  den_avg_saving  \
# 0     69.19    30.81         586020.95          10281.07         4115.76
# 1     85.23    14.77         635118.60          11142.43         3989.74
# 2     89.91    10.09         759537.97          13809.78         5031.07
# 3     87.16    12.84         426055.10           8193.37         2376.76
# 4     85.62    14.38         539304.93          12541.98         4365.20
# 5     88.33    11.67         597470.27          14225.48         3940.17
# 6     80.28    19.72         329619.39           7848.08         2945.88
# 7     88.33    11.67         663834.78          15805.59         5325.36
# 8     86.38    13.62         414498.09          10907.84         4128.34
# 9     78.98    21.02         575536.21          15555.03         4502.84
# 10    87.71    12.29         471453.17          13095.92         4055.72
# 11    81.28    18.72         452734.97          12935.28         3568.01
# 12    87.55    12.45         480483.61          14131.87         3212.72
# 13    89.39    10.61         477038.97          14455.73         3592.16
# 14    86.42    13.58         496336.73          15040.51         4756.42
#
#     den_tot_saving
# 0        234598.35
# 1        227415.12
# 2        276708.93
# 3        123591.71
# 4        187703.76
# 5        165487.10
# 6        123726.80
# 7        223665.26
# 8        156876.90
# 9        166605.12
# 10       146005.87
# 11       124880.19
# 12       109232.54
# 13       118541.18
# 14       156962.02

# %%
import pandas as pd

df = df_clean.copy()

# Fix datatype
df["Payments"] = pd.to_numeric(df["Payments"], errors="coerce")
df["IDSavings"] = pd.to_numeric(df["IDSavings"], errors="coerce")

df["SDX Set"] = df["SDX Set"].apply(lambda x: tuple(x) if isinstance(x, list) else x)
df["Common_PX"] = df["Common_PX"].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# 1 Base Aggregation
df_group = df.groupby(["ADRG"]).agg(
    tot_claims=("InitialDeterminationStatus", "count"),
    app_count=("InitialDeterminationStatus", lambda x: (x == "Approved").sum()),
    den_count=("InitialDeterminationStatus", lambda x: (x == "Denied").sum()),
    tot_payments=("Payments", "sum"),
    avg_payments=("Payments", "mean"),
    #max_payments=("Payments", "max"),
    #min_payments=("Payments", "min"),
    #count_payments=("Payments", "count")
).reset_index()

# 2 % Denied
df_group["per_app"] = (
    df_group["app_count"] / df_group["tot_claims"] * 100
).round(2)

df_group["per_den"] = (
    df_group["den_count"] / df_group["tot_claims"] * 100
).round(2)

# 3 Denied-only aggregation
denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
    ["ADRG"]
).agg(
    den_tot_payments=("Payments", "sum"),
    den_avg_payments=("Payments", "mean"),
    den_avg_saving=("IDSavings", "mean"),
    den_tot_saving=("IDSavings", "sum")
).reset_index()

# 4 Merge
df_group = df_group.merge(denied_stats, on=["ADRG"], how="left")

# 5 Sorting
df_group = df_group.sort_values(by="per_den", ascending=False).reset_index(drop=True)

cols = [
    'tot_payments',
    'avg_payments',
    'per_app',
    'per_den',
    'den_tot_payments',
    'den_avg_payments',
    'den_avg_saving',
    'den_tot_saving'
]

df_group[cols] = df_group[cols].round(2)


df_group.to_excel("Hum_DRG.xlsx")
df_group.head(15)
# Out:
#    ADRG  tot_claims  app_count  den_count  tot_payments  avg_payments  \
# 0   970           1          0          1      16758.54      16758.54
# 1   779           1          0          1       6880.73       6880.73
# 2   597           1          0          1       8100.94       8100.94
# 3   263           2          0          2      48040.01      24020.00
# 4   872         832        288        544    5557436.92       6679.61
# 5   854         196         87        109    2696859.56      13759.49
# 6   822           2          1          1      16225.85       8112.92
# 7   662           2          1          1      38575.73      19287.86
# 8   625           2          1          1      48998.84      24499.42
# 9   864           2          1          1      11702.62       5851.31
# 10  853         980        576        404   34539160.40      35244.04
# 11  871        5111       3052       2059   67952751.81      13295.39
# 12  113           3          2          1      51055.25      17018.42
# 13  974          22         15          7     478274.16      21739.73
# 14  846           7          5          2     158034.53      22576.36
#
#     per_app  per_den  den_tot_payments  den_avg_payments  den_avg_saving  \
# 0      0.00   100.00          16758.54          16758.54         5022.60
# 1      0.00   100.00           6880.73           6880.73         1074.38
# 2      0.00   100.00           8100.94           8100.94         3353.91
# 3      0.00   100.00          48040.01          24020.00         2916.61
# 4     34.62    65.38        3625873.94           6665.21         1488.15
# 5     44.39    55.61        1448114.78          13285.46         3016.57
# 6     50.00    50.00           8493.73           8493.73         2294.09
# 7     50.00    50.00          19165.95          19165.95         8948.35
# 8     50.00    50.00          16589.46          16589.46         6776.49
# 9     50.00    50.00           4932.58           4932.58          321.10
# 10    58.78    41.22       13979485.98          34602.69        10082.42
# 11    59.71    40.29       26896229.15          13062.76         4619.59
# 12    66.67    33.33          18089.21          18089.21         8811.08
# 13    68.18    31.82         149162.17          21308.88        10593.57
# 14    71.43    28.57          34118.85          17059.42         8874.62
#
#     den_tot_saving
# 0          5022.60
# 1          1074.38
# 2          3353.91
# 3          5833.22
# 4        809553.16
# 5        328806.50
# 6          2294.09
# 7          8948.35
# 8          6776.49
# 9           321.10
# 10      4073298.06
# 11      9511732.10
# 12         8811.08
# 13        74155.01
# 14        17749.25

# %%
import pandas as pd

df = df_clean.copy()

# Fix datatype
df["Payments"] = pd.to_numeric(df["Payments"], errors="coerce")
df["IDSavings"] = pd.to_numeric(df["IDSavings"], errors="coerce")

df["SDX Set"] = df["SDX Set"].apply(lambda x: tuple(x) if isinstance(x, list) else x)
df["Common_PX"] = df["Common_PX"].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# 1 Base Aggregation
df_group = df.groupby(["Provider_ID","ADRG"]).agg(
    tot_claims=("InitialDeterminationStatus", "count"),
    app_count=("InitialDeterminationStatus", lambda x: (x == "Approved").sum()),
    den_count=("InitialDeterminationStatus", lambda x: (x == "Denied").sum()),
    tot_payments=("Payments", "sum"),
    avg_payments=("Payments", "mean"),
    #max_payments=("Payments", "max"),
    #min_payments=("Payments", "min"),
    #count_payments=("Payments", "count")
).reset_index()

# 2 % Denied
df_group["per_app"] = (
    df_group["app_count"] / df_group["tot_claims"] * 100
).round(2)

df_group["per_den"] = (
    df_group["den_count"] / df_group["tot_claims"] * 100
).round(2)

# 3 Denied-only aggregation
denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
    ["Provider_ID","ADRG"]
).agg(
    den_tot_payments=("Payments", "sum"),
    den_avg_payments=("Payments", "mean"),
    den_avg_saving=("IDSavings", "mean"),
    den_tot_saving=("IDSavings", "sum")
).reset_index()

# 4 Merge
df_group = df_group.merge(denied_stats, on=["Provider_ID","ADRG"], how="left")

# 5 Sorting
df_group = df_group.sort_values(by="den_count", ascending=False).reset_index(drop=True)

cols = [
    'tot_payments',
    'avg_payments',
    'per_app',
    'per_den',
    'den_tot_payments',
    'den_avg_payments',
    'den_avg_saving',
    'den_tot_saving'
]

df_group[cols] = df_group[cols].round(2)


df_group.to_excel("Hum_Provider_DRG.xlsx")
df_group.head(15)
# Out:
#    Provider_ID ADRG  tot_claims  app_count  den_count  tot_payments  \
# 0   630845288C  871          50         25         25     623676.20
# 1    730700090  871          24          6         18     218503.05
# 2    560928089  871          36         21         15     475016.33
# 3   000047750D  871          28         13         15     339893.65
# 4   000059420E  871          41         27         14     607497.41
# 5   000021832C  683          40         26         14     209516.79
# 6   000055091C  871          18          5         13     270762.51
# 7    560585243  871          25         12         13     328882.62
# 8    000198532  871          27         14         13     396904.33
# 9   000098152D  871          24         11         13     362299.46
# 10  581123037T  871          33         21         12     373281.30
# 11  853777599B  871          29         17         12     427586.34
# 12   730657693  871          21         10         11     182620.63
# 13  741180155W  871          17          6         11     305723.16
# 14  000066600C  871          28         17         11     386573.10
#
#     avg_payments  per_app  per_den  den_tot_payments  den_avg_payments  \
# 0       12473.52    50.00    50.00         308200.16          12328.01
# 1        9104.29    25.00    75.00         149472.10           8304.01
# 2       13194.90    58.33    41.67         194341.76          12956.12
# 3       12139.06    46.43    53.57         174800.81          11653.39
# 4       14817.01    65.85    34.15         190344.70          13596.05
# 5        5237.92    65.00    35.00          76298.43           5449.89
# 6       15042.36    27.78    72.22         190528.84          14656.06
# 7       13155.30    48.00    52.00         170510.03          13116.16
# 8       14700.16    51.85    48.15         202260.49          15558.50
# 9       15095.81    45.83    54.17         188966.29          14535.87
# 10      11311.55    63.64    36.36         142197.05          11849.75
# 11      14744.36    58.62    41.38         183757.37          15313.11
# 12       8696.22    47.62    52.38          92923.42           8447.58
# 13      17983.72    35.29    64.71         160029.26          14548.11
# 14      13806.18    60.71    39.29         141136.12          12830.56
#
#     den_avg_saving  den_tot_saving
# 0          3358.10        83952.55
# 1          3606.63        64919.26
# 2          4768.21        71523.16
# 3          4915.31        73729.61
# 4          4861.97        68067.62
# 5           771.78        10804.86
# 6          4601.23        59816.02
# 7          4895.09        63636.17
# 8          5302.25        68929.29
# 9          4862.41        63211.38
# 10         5610.79        67329.53
# 11         6599.98        79199.76
# 12         3683.55        40519.01
# 13         4845.76        53303.33
# 14         3682.69        40509.54

# %%
import pandas as pd

df = df_clean.copy()

# Fix datatype
df["Payments"] = pd.to_numeric(df["Payments"], errors="coerce")
df["IDSavings"] = pd.to_numeric(df["IDSavings"], errors="coerce")

df["SDX Set"] = df["SDX Set"].apply(lambda x: tuple(x) if isinstance(x, list) else x)
df["Common_PX"] = df["Common_PX"].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# 1 Base Aggregation
df_group = df.groupby(["ADRG","PRIM_DX","SDX Set","Common_PX"]).agg(
    tot_claims=("InitialDeterminationStatus", "count"),
    app_count=("InitialDeterminationStatus", lambda x: (x == "Approved").sum()),
    den_count=("InitialDeterminationStatus", lambda x: (x == "Denied").sum()),
    tot_payments=("Payments", "sum"),
    avg_payments=("Payments", "mean"),
    #max_payments=("Payments", "max"),
    #min_payments=("Payments", "min"),
    #count_payments=("Payments", "count")
).reset_index()

# 2 % Denied
df_group["per_app"] = (
    df_group["app_count"] / df_group["tot_claims"] * 100
).round(2)

df_group["per_den"] = (
    df_group["den_count"] / df_group["tot_claims"] * 100
).round(2)

# 3 Denied-only aggregation
denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
    ["ADRG","PRIM_DX","SDX Set","Common_PX"]
).agg(
    den_tot_payments=("Payments", "sum"),
    den_avg_payments=("Payments", "mean"),
    den_avg_saving=("IDSavings", "mean"),
    den_tot_saving=("IDSavings", "sum")
).reset_index()

# 4 Merge
df_group = df_group.merge(denied_stats, on=["ADRG","PRIM_DX","SDX Set","Common_PX"], how="left")

# 5 Sorting
df_group = df_group.sort_values(by="den_count", ascending=False).reset_index(drop=True)

cols = [
    'tot_payments',
    'avg_payments',
    'per_app',
    'per_den',
    'den_tot_payments',
    'den_avg_payments',
    'den_avg_saving',
    'den_tot_saving'
]

df_group[cols] = df_group[cols].round(2)


df_group.to_excel("Hum_DRG_PDX_SDX_PX.xlsx")
df_group.head(15)
# Out:
#    ADRG PRIM_DX         SDX Set Common_PX  tot_claims  app_count  den_count  \
# 0   189   J9621        (J9622,)        ()         425        336         89
# 1   190    J441  (J9621, J9622)        ()         444        362         82
# 2   872    A419        (R6520,)        ()         109         39         70
# 3   189   J9601    No MCC or CC        ()          84         25         59
# 4   871    A419   (J189, J9601)        ()          71         17         54
# 5   871    A419         (J189,)        ()          52          8         44
# 6   189   J9601         (J189,)        ()          89         52         37
# 7   689   N3000        (G9341,)        ()          63         30         33
# 8   190    J441        (J9621,)        ()          45         13         32
# 9   871    A419        (G9341,)        ()          36          5         31
# 10  872   A4151        (R6520,)        ()          46         17         29
# 11  689    N390        (G9341,)        ()          85         56         29
# 12  189   J9621         (J189,)        ()          54         28         26
# 13  189   J9601        (J9602,)        ()         114         88         26
# 14  193    J189        (J9601,)        ()          54         28         26
#
#     tot_payments  avg_payments  per_app  per_den  den_tot_payments  \
# 0     3472384.49       8170.32    79.06    20.94         708478.56
# 1     3443967.01       7756.68    81.53    18.47         649936.83
# 2      702596.90       6445.84    35.78    64.22         446806.95
# 3      798707.96       9508.43    29.76    70.24         527005.77
# 4      866803.07      12208.49    23.94    76.06         665381.05
# 5      570254.54      10966.43    15.38    84.62         491680.71
# 6      901943.19      10134.19    58.43    41.57         330377.89
# 7      486789.70       7726.82    47.62    52.38         267346.00
# 8      306127.13       6802.83    28.89    71.11         213509.04
# 9      456827.94      12689.66    13.89    86.11         395564.50
# 10     289444.62       6292.27    36.96    63.04         181423.49
# 11     655273.23       7709.10    65.88    34.12         215588.67
# 12     445463.56       8249.33    51.85    48.15         203127.09
# 13     957246.72       8396.90    77.19    22.81         203617.66
# 14     426507.34       7898.28    51.85    48.15         227855.27
#
#     den_avg_payments  den_avg_saving  den_tot_saving
# 0            7960.43         2526.92       224895.67
# 1            7926.06         1826.15       149744.25
# 2            6382.96         1372.55        96078.83
# 3            8932.30         3805.70       224536.24
# 4           12321.87         5782.36       312247.66
# 5           11174.56         5706.76       251097.37
# 6            8929.13         3093.29       114451.90
# 7            8101.39         2401.16        79238.16
# 8            6672.16         1834.61        58707.45
# 9           12760.15         5873.56       182080.36
# 10           6255.98         1516.32        43973.16
# 11           7434.09         2312.35        67058.27
# 12           7812.58         2302.41        59862.65
# 13           7831.45         2821.05        73347.26
# 14           8763.66         3179.98        82679.61

# %%
import pandas as pd

df = df_clean.copy()

# Fix datatype
df["Payments"] = pd.to_numeric(df["Payments"], errors="coerce")
df["IDSavings"] = pd.to_numeric(df["IDSavings"], errors="coerce")

df["SDX Set"] = df["SDX Set"].apply(lambda x: tuple(x) if isinstance(x, list) else x)
df["Common_PX"] = df["Common_PX"].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# 1 Base Aggregation
df_group = df.groupby(["Provider_ID","ADRG","PRIM_DX","SDX Set","Common_PX"]).agg(
    tot_claims=("InitialDeterminationStatus", "count"),
    app_count=("InitialDeterminationStatus", lambda x: (x == "Approved").sum()),
    den_count=("InitialDeterminationStatus", lambda x: (x == "Denied").sum()),
    tot_payments=("Payments", "sum"),
    avg_payments=("Payments", "mean"),
    #max_payments=("Payments", "max"),
    #min_payments=("Payments", "min"),
    #count_payments=("Payments", "count")
).reset_index()

# 2 % Denied
df_group["per_app"] = (
    df_group["app_count"] / df_group["tot_claims"] * 100
).round(2)

df_group["per_den"] = (
    df_group["den_count"] / df_group["tot_claims"] * 100
).round(2)

# 3 Denied-only aggregation
denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
    ["Provider_ID","ADRG","PRIM_DX","SDX Set","Common_PX"]
).agg(
    den_tot_payments=("Payments", "sum"),
    den_avg_payments=("Payments", "mean"),
    den_avg_saving=("IDSavings", "mean"),
    den_tot_saving=("IDSavings", "sum")
).reset_index()

# 4 Merge
df_group = df_group.merge(denied_stats, on=["Provider_ID","ADRG","PRIM_DX","SDX Set","Common_PX"], how="left")

# 5 Sorting
df_group = df_group.sort_values(by="den_count", ascending=False).reset_index(drop=True)

cols = [
    'tot_payments',
    'avg_payments',
    'per_app',
    'per_den',
    'den_tot_payments',
    'den_avg_payments',
    'den_avg_saving',
    'den_tot_saving'
]

df_group[cols] = df_group[cols].round(2)


df_group.to_excel("Hum_DRG_Provider_PDX_SDX_PX.xlsx")
df_group.head(15)
# Out:
#      Provider_ID ADRG PRIM_DX                    SDX Set Common_PX  \
# 0     550357050E  189   J9621                   (J9622,)        ()
# 1      000198448  872    A419                   (R6520,)        ()
# 2      000198266  190    J441             (J9621, J9622)        ()
# 3      730579286  871    A419  (E43, J189, J9601, J9602)        ()
# 4     000047750D  871    A419                    (J189,)        ()
# 5     386006309A  189   J9621                   (J9622,)        ()
# 6      581725656  190    J441                   (J9601,)        ()
# 7     593458145N  872    A419                   (R6520,)        ()
# 8      610654587  190    J441             (J9621, J9622)        ()
# 9      581725656  190    J441                   (J9621,)        ()
# 10    000021832C  689    N390                   (G9341,)        ()
# 11     841343242  177    U071                   (J9601,)        ()
# 12    581123037T  189   J9601                   (J9602,)        ()
# 13  000018589001  189   J9621               No MCC or CC        ()
# 14    752932824C  189   J9601                  (J45901,)        ()
#
#     tot_claims  app_count  den_count  tot_payments  avg_payments  per_app  \
# 0            7          4          3      54106.27       7729.47    57.14
# 1            3          0          3      14447.48       4815.83     0.00
# 2            7          4          3     115532.95      16504.71    57.14
# 3            2          0          2      23061.79      11530.90     0.00
# 4            2          0          2      19536.91       9768.46     0.00
# 5            3          1          2      29495.00       9831.67    33.33
# 6            2          0          2       9873.82       4936.91     0.00
# 7            2          0          2      15477.25       7738.62     0.00
# 8            4          2          2      25742.99       6435.75    50.00
# 9            2          0          2       9873.82       4936.91     0.00
# 10           2          0          2      10745.86       5372.93     0.00
# 11           2          0          2      45198.41      22599.20     0.00
# 12           2          0          2      13599.22       6799.61     0.00
# 13           2          0          2      10780.25       5390.12     0.00
# 14           2          0          2      17552.62       8776.31     0.00
#
#     per_den  den_tot_payments  den_avg_payments  den_avg_saving  \
# 0     42.86          21764.27           7254.76         2533.88
# 1    100.00          14447.48           4815.83         1030.05
# 2     42.86          49502.29          16500.76         1887.46
# 3    100.00          23061.79          11530.90         2537.26
# 4    100.00          19536.91           9768.46         5792.76
# 5     66.67          20186.00          10093.00         4438.42
# 6    100.00           9873.82           4936.91         1447.62
# 7    100.00          15477.25           7738.62         1229.22
# 8     50.00          12926.07           6463.04         1600.16
# 9    100.00           9873.82           4936.91         1053.23
# 10   100.00          10745.86           5372.93          783.52
# 11   100.00          45198.41          22599.20         5550.28
# 12   100.00          13599.22           6799.61         2450.56
# 13   100.00          10780.25           5390.12         2605.89
# 14   100.00          17552.62           8776.31         3519.05
#
#     den_tot_saving
# 0          7601.64
# 1          3090.16
# 2          5662.37
# 3          5074.52
# 4         11585.53
# 5          8876.85
# 6          2895.25
# 7          2458.45
# 8          3200.31
# 9          2106.46
# 10         1567.04
# 11        11100.57
# 12         4901.12
# 13         5211.78
# 14         7038.10

# %%
import numpy as np

df_clean["LOS_bin"] = np.select(
    [
        df_clean["LOS"] <= 3,
        (df_clean["LOS"] >= 4) & (df_clean["LOS"] <= 30),
        df_clean["LOS"] >= 31
    ],
    [
        df_clean["LOS"].astype(str),
        (
            (4 + ((df_clean["LOS"] - 4) // 3) * 3).astype(str)
            + "-"
            + (6 + ((df_clean["LOS"] - 4) // 3) * 3).astype(str)
        ),
        "31+"
    ]
)

# %%
import pandas as pd

df = df_clean.copy()

# Fix datatype
df["Payments"] = pd.to_numeric(df["Payments"], errors="coerce")
df["IDSavings"] = pd.to_numeric(df["IDSavings"], errors="coerce")

df["SDX Set"] = df["SDX Set"].apply(lambda x: tuple(x) if isinstance(x, list) else x)
df["Common_PX"] = df["Common_PX"].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# 1 Base Aggregation
df_group = df.groupby(["LOS_bin"]).agg(
    tot_claims=("InitialDeterminationStatus", "count"),
    app_count=("InitialDeterminationStatus", lambda x: (x == "Approved").sum()),
    den_count=("InitialDeterminationStatus", lambda x: (x == "Denied").sum()),
    tot_payments=("Payments", "sum"),
    avg_payments=("Payments", "mean"),
    #max_payments=("Payments", "max"),
    #min_payments=("Payments", "min"),
    #count_payments=("Payments", "count")
).reset_index()

# 2 % Denied
df_group["per_app"] = (
    df_group["app_count"] / df_group["tot_claims"] * 100
).round(2)

df_group["per_den"] = (
    df_group["den_count"] / df_group["tot_claims"] * 100
).round(2)

# 3 Denied-only aggregation
denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
    ["LOS_bin"]
).agg(
    den_tot_payments=("Payments", "sum"),
    den_avg_payments=("Payments", "mean"),
    den_avg_saving=("IDSavings", "mean"),
    den_tot_saving=("IDSavings", "sum")
).reset_index()

# 4 Merge
df_group = df_group.merge(denied_stats, on=["LOS_bin"], how="left")

# 5 Sorting
df_group = df_group.sort_values(by="per_den", ascending=False).reset_index(drop=True)

cols = [
    'tot_payments',
    'avg_payments',
    'per_app',
    'per_den',
    'den_tot_payments',
    'den_avg_payments',
    'den_avg_saving',
    'den_tot_saving'
]

df_group[cols] = df_group[cols].round(2)
df_group.to_excel("Hum_los.xlsx")
df_group.head(15)
# Out:
#    LOS_bin  tot_claims  app_count  den_count  tot_payments  avg_payments  \
# 0    22-24        1103        837        266  2.418081e+07      21922.76
# 1    25-27         603        472        131  1.427129e+07      23667.15
# 2    19-21        1906       1531        375  3.926871e+07      20602.68
# 3    16-18        2957       2461        496  5.560872e+07      18805.79
# 4      31+         676        567        109  2.098291e+07      31039.80
# 5    28-30         399        338         61  1.028424e+07      25775.04
# 6        3        6826       5977        849  6.838419e+07      10018.19
# 7        2        5295       4647        648  5.230313e+07       9877.83
# 8    10-12        6390       5626        764  9.562637e+07      14965.00
# 9      4-6       18187      16042       2145  1.997940e+08      10985.54
# 10     7-9       10680       9444       1236  1.400262e+08      13111.07
# 11   13-15        4322       3841        481  7.407738e+07      17139.61
# 12       1        3933       3601        332  3.691565e+07       9386.13
# 13       0         784        735         49  8.324162e+06      10617.55
#
#     per_app  per_den  den_tot_payments  den_avg_payments  den_avg_saving  \
# 0     75.88    24.12        5797977.32          21796.91         6190.66
# 1     78.28    21.72        2484315.69          18964.24         5981.39
# 2     80.33    19.67        7165335.35          19107.56         5537.31
# 3     83.23    16.77        8480606.77          17098.00         5515.79
# 4     83.88    16.12        2353792.50          21594.43         6236.12
# 5     84.71    15.29        1166983.68          19130.88         5509.79
# 6     87.56    12.44        8375513.50           9865.15         3287.07
# 7     87.76    12.24        6161270.77           9508.13         2947.96
# 8     88.04    11.96        9651989.50          12633.49         4228.87
# 9     88.21    11.79       21587033.53          10063.89         3269.43
# 10    88.43    11.57       13911687.88          11255.41         3749.23
# 11    88.87    11.13        7429738.19          15446.44         5186.96
# 12    91.56     8.44        3035005.25           9141.58         2683.83
# 13    93.75     6.25         441070.76           9001.44         2406.29
#
#     den_tot_saving
# 0       1646716.75
# 1        783562.29
# 2       2076490.99
# 3       2735829.74
# 4        679736.75
# 5        336097.31
# 6       2790725.10
# 7       1910278.90
# 8       3230853.13
# 9       7012934.45
# 10      4634042.78
# 11      2494926.71
# 12       891033.10
# 13       117908.40

# %%
import pandas as pd

df = df_sur_drg.copy()

# Fix datatype
df["Payments"] = pd.to_numeric(df["Payments"], errors="coerce")
df["IDSavings"] = pd.to_numeric(df["IDSavings"], errors="coerce")

df["SDX Set"] = df["SDX Set"].apply(lambda x: tuple(x) if isinstance(x, list) else x)
df["Common_PX"] = df["Common_PX"].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# 1 Base Aggregation
df_group = df.groupby(["Provider_ID","LOS_bin"]).agg(
    tot_claims=("InitialDeterminationStatus", "count"),
    app_count=("InitialDeterminationStatus", lambda x: (x == "Approved").sum()),
    den_count=("InitialDeterminationStatus", lambda x: (x == "Denied").sum()),
    tot_payments=("Payments", "sum"),
    avg_payments=("Payments", "mean"),
    #max_payments=("Payments", "max"),
    #min_payments=("Payments", "min"),
    #count_payments=("Payments", "count")
).reset_index()

# 2 % Denied
df_group["per_app"] = (
    df_group["app_count"] / df_group["tot_claims"] * 100
).round(2)

df_group["per_den"] = (
    df_group["den_count"] / df_group["tot_claims"] * 100
).round(2)

# 3 Denied-only aggregation
denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
    ["Provider_ID","LOS_bin"]
).agg(
    den_tot_payments=("Payments", "sum"),
    den_avg_payments=("Payments", "mean"),
    den_avg_saving=("IDSavings", "mean"),
    den_tot_saving=("IDSavings", "sum")
).reset_index()

# 4 Merge
df_group = df_group.merge(denied_stats, on=["Provider_ID","LOS_bin"], how="left")

# 5 Sorting
df_group = df_group.sort_values(by="den_count", ascending=False).reset_index(drop=True)

cols = [
    'tot_payments',
    'avg_payments',
    'per_app',
    'per_den',
    'den_tot_payments',
    'den_avg_payments',
    'den_avg_saving',
    'den_tot_saving'
]

df_group[cols] = df_group[cols].round(2)


df_group.to_excel("Sur_DRG_Provider_los.xlsx")
df_group.head(15)
# Out:
#    Provider_ID LOS_bin  tot_claims  app_count  den_count  tot_payments  \
# 0   000090250B     4-6          26         22          4     488183.65
# 1    730700090       2           8          4          4     102157.09
# 2   000066600C   13-15          10          7          3     220629.40
# 3   000061694I       2          10          7          3     144259.69
# 4    730700090   10-12           5          2          3     107420.27
# 5    730700090     4-6          13         10          3     161601.82
# 6    736048282     4-6           5          2          3      95459.80
# 7    800818718     4-6           9          6          3     233454.41
# 8    272844767   16-18           3          1          2     101374.92
# 9   000104720F     31+           2          0          2      65963.44
# 10  000021832C       2           5          3          2      80984.83
# 11  000021832C       3           7          5          2     134065.19
# 12  000070893B     4-6           4          2          2      59188.27
# 13  000258619B     4-6          10          8          2     265147.87
# 14  000060303R   13-15           4          2          2     110164.37
#
#     avg_payments  per_app  per_den  den_tot_payments  den_avg_payments  \
# 0       18776.29    84.62    15.38          93917.87          23479.47
# 1       12769.64    50.00    50.00          55029.36          13757.34
# 2       22062.94    70.00    30.00          55720.51          18573.50
# 3       14425.97    70.00    30.00          36512.09          12170.70
# 4       21484.05    40.00    60.00          36754.67          12251.56
# 5       12430.91    76.92    23.08          57576.24          19192.08
# 6       19091.96    40.00    60.00          58224.94          19408.31
# 7       25939.38    66.67    33.33          92144.41          30714.80
# 8       33791.64    33.33    66.67          60638.51          30319.25
# 9       32981.72     0.00   100.00          65963.44          32981.72
# 10      16196.97    60.00    40.00          21083.22          10541.61
# 11      19152.17    71.43    28.57          42062.35          21031.18
# 12      14797.07    50.00    50.00          32247.62          16123.81
# 13      26514.79    80.00    20.00          80644.24          40322.12
# 14      27541.09    50.00    50.00          48311.08          24155.54
#
#     den_avg_saving  den_tot_saving
# 0          4192.47        16769.89
# 1          6346.73        25386.93
# 2          7339.24        22017.71
# 3          4475.01        13425.03
# 4          2506.30         7518.89
# 5          7765.69        23297.07
# 6         10737.87        32213.60
# 7         12701.89        38105.68
# 8         10462.83        20925.66
# 9         11453.97        22907.94
# 10         4309.48         8618.96
# 11         3201.05         6402.10
# 12         9365.78        18731.56
# 13        21716.61        43433.21
# 14         4587.99         9175.98

# %%
# Find maximum LOS
max_los = df_clean["AGE"].max()

# Create bins of size 10 directly from 0 to max
bins = list(range(0, int(max_los) + 10 + 1, 10))  # 0,10,20,30,... up to max

# Create labels for each bin
labels = [f"{bins[i]}-{bins[i+1]}" for i in range(len(bins)-1)]

# Assign LOS bins
df_clean["AGE_Bin"] = pd.cut(
    df_clean["AGE"],
    bins=bins,
    labels=labels,
    include_lowest=True,
    right=False
)
df_clean.shape
# Out:
# (64061, 39)

# %%
import pandas as pd

df = df_clean.copy()

# Fix datatype
df["Payments"] = pd.to_numeric(df["Payments"], errors="coerce")
df["IDSavings"] = pd.to_numeric(df["IDSavings"], errors="coerce")

df["SDX Set"] = df["SDX Set"].apply(lambda x: tuple(x) if isinstance(x, list) else x)
df["Common_PX"] = df["Common_PX"].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# 1 Base Aggregation
df_group = df.groupby(["AGE_Bin"]).agg(
    tot_claims=("InitialDeterminationStatus", "count"),
    app_count=("InitialDeterminationStatus", lambda x: (x == "Approved").sum()),
    den_count=("InitialDeterminationStatus", lambda x: (x == "Denied").sum()),
    tot_payments=("Payments", "sum"),
    avg_payments=("Payments", "mean"),
    #max_payments=("Payments", "max"),
    #min_payments=("Payments", "min"),
    #count_payments=("Payments", "count")
).reset_index()

# 2 % Denied
df_group["per_app"] = (
    df_group["app_count"] / df_group["tot_claims"] * 100
).round(2)

df_group["per_den"] = (
    df_group["den_count"] / df_group["tot_claims"] * 100
).round(2)

# 3 Denied-only aggregation
denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
    ["AGE_Bin"]
).agg(
    den_tot_payments=("Payments", "sum"),
    den_avg_payments=("Payments", "mean"),
    den_avg_saving=("IDSavings", "mean"),
    den_tot_saving=("IDSavings", "sum")
).reset_index()

# 4 Merge
df_group = df_group.merge(denied_stats, on=["AGE_Bin"], how="left")

# 5 Sorting
df_group = df_group.sort_values(by="den_count", ascending=False).reset_index(drop=True)

cols = [
    'tot_payments',
    'avg_payments',
    'per_app',
    'per_den',
    'den_tot_payments',
    'den_avg_payments',
    'den_avg_saving',
    'den_tot_saving'
]

df_group[cols] = df_group[cols].round(2)


df_group.to_excel("Hum_age.xlsx")
df_group.head(15)
# Out:
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\1968857429.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_group = df.groupby(["AGE_Bin"]).agg(
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_20648\1968857429.py:34: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
#    AGE_Bin  tot_claims  app_count  den_count  tot_payments  avg_payments  \
# 0    70-75       11938      10479       1459  1.600292e+08      13405.03
# 1    75-80       10746       9379       1367  1.417021e+08      13186.50
# 2    65-70       11387      10116       1271  1.549776e+08      13610.05
# 3    80-85        8329       7226       1103  1.085827e+08      13036.70
# 4    85-90        5258       4524        734  6.593181e+07      12539.33
# 5    60-65        5303       4656        647  7.040340e+07      13276.15
# 6    55-60        3067       2712        355  4.097787e+07      13360.90
# 7    90-95        2340       2005        335  2.843901e+07      12153.43
# 8    50-55        1789       1583        206  2.252004e+07      12588.06
# 9    45-50        1133       1006        127  1.469436e+07      12969.43
# 10  95-100         686        587         99  7.981859e+06      11635.36
# 11   40-45         777        689         88  9.942175e+06      12795.59
# 12   35-40         532        464         68  6.338083e+06      11913.69
# 13   30-35         358        323         35  3.673175e+06      10260.27
# 14   25-30         208        186         22  1.972503e+06       9483.19
#
#     per_app  per_den  den_tot_payments  den_avg_payments  den_avg_saving  \
# 0     87.78    12.22       18235997.71          12498.97         4081.69
# 1     87.28    12.72       16922023.96          12378.95         3786.18
# 2     88.84    11.16       16218668.82          12760.56         4168.11
# 3     86.76    13.24       13520914.15          12258.31         3929.95
# 4     86.04    13.96        8748951.30          11919.55         3719.75
# 5     87.80    12.20        8072064.53          12476.14         3866.66
# 6     88.43    11.57        4523500.46          12742.25         4137.54
# 7     85.68    14.32        3884206.51          11594.65         3674.30
# 8     88.49    11.51        2624771.64          12741.61         4265.64
# 9     88.79    11.21        1558009.14          12267.79         3548.59
# 10    85.57    14.43        1084699.03          10956.56         3589.63
# 11    88.67    11.33        1080069.18          12273.51         4280.51
# 12    87.22    12.78         757818.12          11144.38         4165.54
# 13    90.22     9.78         324248.63           9264.25         3644.62
# 14    89.42    10.58         236688.43          10758.56         3539.15
#
#     den_tot_saving
# 0       5955178.82
# 1       5175704.48
# 2       5297664.88
# 3       4334732.81
# 4       2730294.21
# 5       2501730.11
# 6       1468825.51
# 7       1230891.81
# 8        878722.13
# 9        450671.40
# 10       355373.35
# 11       376684.82
# 12       283257.01
# 13       127561.71
# 14        77861.30

# %%
import pandas as pd

df = df_sur_drg.copy()

# Fix datatype
df["Payments"] = pd.to_numeric(df["Payments"], errors="coerce")
df["IDSavings"] = pd.to_numeric(df["IDSavings"], errors="coerce")

df["SDX Set"] = df["SDX Set"].apply(lambda x: tuple(x) if isinstance(x, list) else x)
df["Common_PX"] = df["Common_PX"].apply(lambda x: tuple(x) if isinstance(x, list) else x)

# 1 Base Aggregation
df_group = df.groupby(["Provider_ID","AGE_Bin"]).agg(
    tot_claims=("InitialDeterminationStatus", "count"),
    app_count=("InitialDeterminationStatus", lambda x: (x == "Approved").sum()),
    den_count=("InitialDeterminationStatus", lambda x: (x == "Denied").sum()),
    tot_payments=("Payments", "sum"),
    avg_payments=("Payments", "mean"),
    #max_payments=("Payments", "max"),
    #min_payments=("Payments", "min"),
    #count_payments=("Payments", "count")
).reset_index()

# 2 % Denied
df_group["per_app"] = (
    df_group["app_count"] / df_group["tot_claims"] * 100
).round(2)

df_group["per_den"] = (
    df_group["den_count"] / df_group["tot_claims"] * 100
).round(2)

# 3 Denied-only aggregation
denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
    ["Provider_ID","AGE_Bin"]
).agg(
    den_tot_payments=("Payments", "sum"),
    den_avg_payments=("Payments", "mean"),
    den_avg_saving=("IDSavings", "mean"),
    den_tot_saving=("IDSavings", "sum")
).reset_index()

# 4 Merge
df_group = df_group.merge(denied_stats, on=["Provider_ID","AGE_Bin"], how="left")

# 5 Sorting
df_group = df_group.sort_values(by="den_count", ascending=False).reset_index(drop=True)

cols = [
    'tot_payments',
    'avg_payments',
    'per_app',
    'per_den',
    'den_tot_payments',
    'den_avg_payments',
    'den_avg_saving',
    'den_tot_saving'
]

df_group[cols] = df_group[cols].round(2)

df_group.to_excel("Sur_DRG_Provider_age.xlsx")
df_group.head(15)
# Out:
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_12440\519229250.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_group = df.groupby(["Provider_ID","AGE_Bin"]).agg(
# C:\Users\Arunkumara\AppData\Local\Temp\ipykernel_12440\519229250.py:34: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   denied_stats = df[df["InitialDeterminationStatus"] == "Denied"].groupby(
#    Provider_ID AGE_Bin  tot_claims  app_count  den_count  tot_payments  \
# 0   000090250B   70-80          40       35.0        5.0     975675.95
# 1    730700090   50-60          14        9.0        5.0     247608.83
# 2   000104720F   70-80          18       14.0        4.0     436797.04
# 3   566017737F   70-80          26       22.0        4.0     742952.69
# 4    582026750   70-80           4        0.0        4.0     107767.81
# 5   582149128A   70-80          36       32.0        4.0     798739.77
# 6   582190713N   70-80          10        6.0        4.0     217625.86
# 7    800818718   60-70           9        5.0        4.0     272011.29
# 8    272844767   60-70           9        6.0        3.0     327407.26
# 9   000059420E   70-80          42       39.0        3.0     972441.88
# 10  000098152D   70-80          14       11.0        3.0     403617.62
# 11  000062947F   70-80           7        4.0        3.0     227075.07
# 12  000198540A   70-80          26       23.0        3.0     610457.93
# 13  000028386L   70-80          11        8.0        3.0     244541.74
# 14  000061694I   30-40           6        3.0        3.0      91375.09
#
#     avg_payments  per_app  per_den  den_tot_payments  den_avg_payments  \
# 0       24391.90    87.50    12.50         149283.29          29856.66
# 1       17686.34    64.29    35.71          86001.41          17200.28
# 2       24266.50    77.78    22.22         101269.07          25317.27
# 3       28575.10    84.62    15.38          96419.74          24104.94
# 4       26941.95     0.00   100.00         107767.81          26941.95
# 5       22187.22    88.89    11.11         132521.79          33130.45
# 6       21762.59    60.00    40.00         112792.27          28198.07
# 7       30223.48    55.56    44.44         149712.17          37428.04
# 8       36378.58    66.67    33.33         108113.43          36037.81
# 9       23153.38    92.86     7.14          87016.88          29005.63
# 10      28829.83    78.57    21.43          85532.09          28510.70
# 11      32439.30    57.14    42.86         112600.22          37533.41
# 12      23479.15    88.46    11.54          69992.92          23330.97
# 13      22231.07    72.73    27.27          75591.43          25197.14
# 14      15229.18    50.00    50.00          31856.61          10618.87
#
#     den_avg_saving  den_tot_saving
# 0          4357.03        21785.17
# 1          9131.76        45658.78
# 2         11895.00        47580.00
# 3         11561.39        46245.56
# 4         10625.01        42500.03
# 5          5166.00        20664.02
# 6          8323.04        33292.18
# 7         13942.22        55768.90
# 8         10989.40        32968.21
# 9          8063.82        24191.46
# 10        11539.28        34617.84
# 11         8856.75        26570.25
# 12         9862.27        29586.82
# 13         3695.75        11087.26
# 14         3947.06        11841.17
